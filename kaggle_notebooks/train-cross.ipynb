# %%
# !pip install datasets==2.11
# !pip install faiss-cpu
# !pip install pyvi
# !pip install sentence_transformers

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !git clone https://github.com/coangquang/legal_retrieval.git
# %cd legal_retrieval
# !mkdir outputs
# !mkdir outputs/cross

# %%
# !python  cross/train_cross.py   \
    --scorpus_file /kaggle/input/processed/scorpus.csv   \
    --file_dir /kaggle/input/processed  \
    --json_dir /kaggle/input/stage2-mlm-15  \
    --cross_checkpoint vinai/phobert-base-v2   \
    --cross_num_epochs 1   \
    --cross_batch_size 32   \
    --cross_max_len 256   \
    --cross_lr 0.00001   \
    --cross_threshold 0.5   \
    --cross_no_negs 50   \
    --cross_eval_steps 400   \
    --cross_save_path outputs/cross
