# %%
# !pip install faiss-gpu
# !pip install pyvi
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 18.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 53.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 76.8 MB/s eta 0:00:00:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 91.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 10.1 MB/s eta 0:00:00
# ...
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=36cd0eb70da55c603f9d029f8b2e66dc788ed1cbde873edf33dc99137c89a287
# ...

# %%
# !git clone https://github.com/coangquang/ltr_chunk.git
# %cd ltr_chunk
# Out:
# Cloning into 'ltr_chunk'...
# remote: Enumerating objects: 1030, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 1030 (delta 101), reused 90 (delta 49), pack-reused 883
# Receiving objects: 100% (1030/1030), 227.92 KiB | 1.53 MiB/s, done.
# Resolving deltas: 100% (758/758), done.
# /kaggle/working/ltr_chunk

# %%
# !python src/demo_notebook.py \
    --encoder /kaggle/input/kd9600final \
    --corpus_file /kaggle/input/corpus/zalo_corpus.csv \
    --max_passage_length 256 \
    --sentence_pooling_method cls \
    --k 30 \
    --batch_size 1024 \
    --input_query "Doanh nghiệp tư nhân có được thuê kế toán dịch vụ không?" \
    --load_embedding /kaggle/input/kd9600final/embeddings.memmap
# Out:
# Args(encoder='/kaggle/input/add3-stage2-10', tokenizer=None, sentence_pooling_method='cls', fp16=False, max_query_length=32, max_passage_length=256, index_factory='Flat', input_query='Doanh nghiệp tư nhân có được thuê kế toán dịch vụ không?', k=30, batch_size=1024, corpus_file='/kaggle/input/zalo-data/zalo_corpus.csv', save_embedding=False, load_embedding='/kaggle/input/add3-stage2-10/embeddings.memmap', save_path='embeddings.memmap')
# ['174/2016/nđ-cp_22', '88/2015/qh13_56', '88/2015/qh13_59', '88/2015/qh13_60', '174/2016/nđ-cp_25', '88/2015/qh13_65', '88/2015/qh13_68', '88/2015/qh13_52', '88/2015/qh13_2', '03/2003/qh11_56', '174/2016/nđ-cp_29', '174/2016/nđ-cp_19', '03/2003/qh11_55', '174/2016/nđ-cp_2', '88/2015/qh13_13', '88/2015/qh13_3', '174/2016/nđ-cp_24', '174/2016/nđ-cp_3', '88/2015/qh13_58', '88/2015/qh13_64', '88/2015/qh13_70', '88/2015/qh13_66', '03/2003/qh11_51', '67/2011/qh12_20', '38/2019/qh14_150']
#
# Chunk 1
# ...
